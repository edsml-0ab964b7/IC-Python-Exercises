# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = cv.imread('zidane.jpg')
plt.imshow(img)

# %%
# opencv B G R 
# matplotlib R G B
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
img_gray = cv2.imread('zidane.jpg', cv.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (720, 1280)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img = cv.imread('zidane.jpg')
img_fixed = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_fixed)

# %%
# 缩放图片。
img_fixed.shape
# Out:
# (720, 1280, 3)

# %%
img_resize = cv2.resize(img_fixed, (500,100))
plt.imshow(img_resize)

# %%
# 0 垂直翻转, 1 水平翻转, -1 水平垂直都翻转。
img_flip = cv2.flip(img_fixed, 1)
plt.imshow(img_flip)

# %%
img_save = cv2.cvtColor(img_flip, cv2.COLOR_RGB2BGR)
cv2.imwrite('./flip_img.jpg', img_save)
# Out:
# True
